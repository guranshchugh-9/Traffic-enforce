# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
feat1 = np.load('../demo_output/-1_c2s2_143002_08.npy')
feat2 = np.load('../demo_output/-1_c5s2_123174_05.npy')
feat3 = np.load('../demo_output/-1_c5s2_123174_03.npy')
feat4 = np.load('../demo_output/dance_crew_logo.npy')

# %%
print(feat1)
print(feat3)
print(feat2)
print(np.sum(feat1 * feat4))
print(np.sum(feat3 * feat4))
print(np.sum(feat3 * feat4))
# Out:
# [[0.02196808 0.01645517 0.01757099 ... 0.01945629 0.02132861 0.0147364 ]]
# [[0.02185491 0.02909111 0.01903413 ... 0.01638194 0.01569647 0.01051721]]
# [[0.01449627 0.02966984 0.01767085 ... 0.01596172 0.01454378 0.01006932]]
# 0.91708064
# 0.9177402
# 0.9177402

# %%
path = '../../deep-person-reid/Market-1501-v15.09.15/gt_bbox/0001_c1s1_002301_00.jpg'
img = cv2.imread(path)
plt.imshow(img)
